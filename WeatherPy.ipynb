# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 619

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | amalapuram
# Processing Record 11 of Set 1 | katsuura
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | tazovskiy
# Processing Record 14 of Set 1 | tommot
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | batouri
# Processing Record 17 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 1 | oktyabrskiy
# Processing Record 19 of Set 1 | puerto escondido
# Processing Record 20 of Set 1 | lucapa
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | meulaboh
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 1 | san ramon
# Processing Record 29 of Set 1 | matameye
# City not found. Skipping...
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | roald
# Processing Record 32 of Set 1 | deputatskiy
# Processing Record 33 of Set 1 | araouane
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | cabedelo
# Processing Record 36 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 1 | iquitos
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | tymovskoye
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | coalinga
# Processing Record 42 of Set 1 | caravelas
# Processing Record 43 of Set 1 | palmer
# Processing Record 44 of Set 1 | kerur
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | souillac
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | cam ranh
# Processing Record 49 of Set 1 | brae
# Processing Record 50 of Set 1 | san pedro
# Processing Record 1 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | poso
# Processing Record 6 of Set 2 | amuntai
# Processing Record 7 of Set 2 | abbeville
# Processing Record 8 of Set 2 | arkadak
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | badou
# Processing Record 11 of Set 2 | gamba
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | tieling
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | gazimurskiy zavod
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | auray
# Processing Record 22 of Set 2 | kruisfontein
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | kargasok
# Processing Record 25 of Set 2 | lorengau
# Processing Record 26 of Set 2 | faya
# Processing Record 27 of Set 2 | lagoa
# Processing Record 28 of Set 2 | lebork
# Processing Record 29 of Set 2 | richards bay
# Processing Record 30 of Set 2 | la rinconada
# Processing Record 31 of Set 2 | fairbanks
# Processing Record 32 of Set 2 | cozumel
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | boyuibe
# Processing Record 36 of Set 2 | arkhangelskoye
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | guerrero negro
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | shingu
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | panaba
# Processing Record 47 of Set 2 | mahibadhoo
# Processing Record 48 of Set 2 | gusau
# Processing Record 49 of Set 2 | haines junction
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | korla
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | porto novo
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | chapais
# Processing Record 9 of Set 3 | sola
# Processing Record 10 of Set 3 | dasoguz
# Processing Record 11 of Set 3 | mocuba
# Processing Record 12 of Set 3 | pisco
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | eydhafushi
# Processing Record 15 of Set 3 | aklavik
# Processing Record 16 of Set 3 | santa cruz cabralia
# Processing Record 17 of Set 3 | cockburn town
# Processing Record 18 of Set 3 | esperance
# Processing Record 19 of Set 3 | xuddur
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | grand gaube
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | costinesti
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | lazaro cardenas
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | sibolga
# Processing Record 30 of Set 3 | borovoy
# Processing Record 31 of Set 3 | mitu
# Processing Record 32 of Set 3 | anito
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | pacific grove
# Processing Record 35 of Set 3 | galle
# Processing Record 36 of Set 3 | dalbandin
# Processing Record 37 of Set 3 | mao
# Processing Record 38 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 3 | kawambwa
# Processing Record 40 of Set 3 | coquimbo
# Processing Record 41 of Set 3 | dingle
# Processing Record 42 of Set 3 | aykhal
# Processing Record 43 of Set 3 | novobirilyussy
# Processing Record 44 of Set 3 | ornskoldsvik
# Processing Record 45 of Set 3 | alofi
# Processing Record 46 of Set 3 | malakal
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | pouebo
# Processing Record 49 of Set 3 | vao
# Processing Record 50 of Set 3 | port macquarie
# Processing Record 1 of Set 4 | magadan
# Processing Record 2 of Set 4 | otradnoye
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | acarau
# Processing Record 5 of Set 4 | olinda
# Processing Record 6 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 4 | padang
# Processing Record 8 of Set 4 | bengkulu
# Processing Record 9 of Set 4 | xining
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | iskateley
# Processing Record 12 of Set 4 | formosa do rio preto
# Processing Record 13 of Set 4 | saldanha
# Processing Record 14 of Set 4 | bilma
# Processing Record 15 of Set 4 | buin
# Processing Record 16 of Set 4 | klaksvik
# Processing Record 17 of Set 4 | narsaq
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | along
# Processing Record 22 of Set 4 | mildura
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | nanortalik
# Processing Record 25 of Set 4 | roebourne
# Processing Record 26 of Set 4 | sainte-anne-des-monts
# Processing Record 27 of Set 4 | dibaya
# City not found. Skipping...
# Processing Record 28 of Set 4 | mecca
# Processing Record 29 of Set 4 | the pas
# Processing Record 30 of Set 4 | nehe
# Processing Record 31 of Set 4 | zwedru
# Processing Record 32 of Set 4 | vierzon
# Processing Record 33 of Set 4 | seymchan
# Processing Record 34 of Set 4 | geraldton
# Processing Record 35 of Set 4 | beringovskiy
# Processing Record 36 of Set 4 | ixtapa
# Processing Record 37 of Set 4 | barcelos
# Processing Record 38 of Set 4 | leyland
# Processing Record 39 of Set 4 | vostok
# Processing Record 40 of Set 4 | port-gentil
# Processing Record 41 of Set 4 | karacakoy
# Processing Record 42 of Set 4 | gavrilov-yam
# Processing Record 43 of Set 4 | nyakabindi
# Processing Record 44 of Set 4 | ye
# City not found. Skipping...
# Processing Record 45 of Set 4 | dalvik
# Processing Record 46 of Set 4 | ponta do sol
# Processing Record 47 of Set 4 | tasiilaq
# Processing Record 48 of Set 4 | yellowknife
# Processing Record 49 of Set 4 | tateyama
# Processing Record 50 of Set 4 | tepalcatepec
# Processing Record 1 of Set 5 | fort-shevchenko
# Processing Record 2 of Set 5 | yar-sale
# Processing Record 3 of Set 5 | muroto
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 5 | outjo
# Processing Record 8 of Set 5 | flinders
# Processing Record 9 of Set 5 | sri aman
# Processing Record 10 of Set 5 | vila franca do campo
# Processing Record 11 of Set 5 | opuwo
# Processing Record 12 of Set 5 | buala
# Processing Record 13 of Set 5 | altay
# Processing Record 14 of Set 5 | novi travnik
# Processing Record 15 of Set 5 | karratha
# Processing Record 16 of Set 5 | golden
# Processing Record 17 of Set 5 | waddan
# Processing Record 18 of Set 5 | cumra
# Processing Record 19 of Set 5 | inhambane
# Processing Record 20 of Set 5 | fuerte olimpo
# Processing Record 21 of Set 5 | coihaique
# Processing Record 22 of Set 5 | avarua
# Processing Record 23 of Set 5 | vila velha
# Processing Record 24 of Set 5 | imeni poliny osipenko
# Processing Record 25 of Set 5 | salinas
# Processing Record 26 of Set 5 | laguna
# Processing Record 27 of Set 5 | ayan
# Processing Record 28 of Set 5 | mehamn
# Processing Record 29 of Set 5 | tiksi
# Processing Record 30 of Set 5 | college
# Processing Record 31 of Set 5 | esso
# Processing Record 32 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | chabahar
# Processing Record 35 of Set 5 | leningradskiy
# Processing Record 36 of Set 5 | novoilinsk
# Processing Record 37 of Set 5 | tongren
# Processing Record 38 of Set 5 | hami
# Processing Record 39 of Set 5 | dikson
# Processing Record 40 of Set 5 | georgetown
# Processing Record 41 of Set 5 | husavik
# Processing Record 42 of Set 5 | harper
# Processing Record 43 of Set 5 | lavrentiya
# Processing Record 44 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 5 | colac
# Processing Record 46 of Set 5 | rawson
# Processing Record 47 of Set 5 | comodoro rivadavia
# Processing Record 48 of Set 5 | bokoro
# Processing Record 49 of Set 5 | suoyarvi
# Processing Record 50 of Set 5 | jefferson city
# Processing Record 1 of Set 6 | hofn
# Processing Record 2 of Set 6 | thunder bay
# Processing Record 3 of Set 6 | kupang
# Processing Record 4 of Set 6 | jumla
# Processing Record 5 of Set 6 | chokurdakh
# Processing Record 6 of Set 6 | dunedin
# Processing Record 7 of Set 6 | uray
# Processing Record 8 of Set 6 | belmonte
# Processing Record 9 of Set 6 | orekhovo-zuevo
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | akdagmadeni
# Processing Record 14 of Set 6 | namibe
# Processing Record 15 of Set 6 | khomutovka
# Processing Record 16 of Set 6 | amalfi
# Processing Record 17 of Set 6 | sobolevo
# Processing Record 18 of Set 6 | singkawang
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | mizan teferi
# Processing Record 21 of Set 6 | sorkjosen
# Processing Record 22 of Set 6 | bathsheba
# Processing Record 23 of Set 6 | yellapur
# Processing Record 24 of Set 6 | saint george
# Processing Record 25 of Set 6 | prieska
# Processing Record 26 of Set 6 | nola
# Processing Record 27 of Set 6 | stokmarknes
# Processing Record 28 of Set 6 | pascagoula
# Processing Record 29 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 6 | moen
# Processing Record 31 of Set 6 | pihuamo
# Processing Record 32 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 6 | walvis bay
# Processing Record 34 of Set 6 | kralendijk
# Processing Record 35 of Set 6 | naze
# Processing Record 36 of Set 6 | dera bugti
# Processing Record 37 of Set 6 | nouakchott
# Processing Record 38 of Set 6 | kenai
# Processing Record 39 of Set 6 | hirara
# Processing Record 40 of Set 6 | nechi
# Processing Record 41 of Set 6 | lewistown
# Processing Record 42 of Set 6 | sao filipe
# Processing Record 43 of Set 6 | pinawa
# Processing Record 44 of Set 6 | goba
# Processing Record 45 of Set 6 | marzuq
# Processing Record 46 of Set 6 | mangrol
# Processing Record 47 of Set 6 | roma
# Processing Record 48 of Set 6 | balikpapan
# Processing Record 49 of Set 6 | torbay
# Processing Record 50 of Set 6 | bandrele
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-90b6f8cf6891> in <module>
#      16         set_count += 1
#      17         record_count = 1
# ---> 18         time.sleep(60)
#      19
#      20     # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
city_data
# Out:
# [{'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 64.38,
#   'Humidity': 67,
#   'Cloudiness': 95,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Date': '2021-12-04 22:36:27'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 68.76,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 18.81,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:36:28'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 72.12,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-12-04 22:34:25'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 55.8,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 13.67,
#   'Country': 'NZ',
#   'Date': '2021-12-04 22:36:28'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.46,
#   'Humidity': 74,
#   'Cloudiness': 7,
#   'Wind Speed': 17.9,
#   'Country': 'PF',
#   'Date': '2021-12-04 22:36:28'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 44.71,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-12-04 22:31:37'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 63.99,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 11.18,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:36:29'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 55.51,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 24.16,
#   'Country': 'CL',
#   'Date': '2021-12-04 22:36:29'},
#  {'City': 'Amalapuram',
#   'Lat': 16.5833,
#   'Lng': 82.0167,
#   'Max Temp': 72.77,
#   'Humidity': 90,
#   'Cloudiness': 73,
#   'Wind Speed': 2.48,
#   'Country': 'IN',
#   'Date': '2021-12-04 22:36:29'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 47.19,
#   'Humidity': 60,
#   'Cloudiness': 7,
#   'Wind Speed': 10.89,
#   'Country': 'JP',
#   'Date': '2021-12-04 22:36:30'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 40.68,
#   'Humidity': 76,
#   'Cloudiness': 87,
#   'Wind Speed': 7.27,
#   'Country': 'US',
#   'Date': '2021-12-04 22:36:18'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': -30.82,
#   'Humidity': 99,
#   'Cloudiness': 35,
#   'Wind Speed': 5.12,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:36:30'},
#  {'City': 'Tommot',
#   'Lat': 58.9564,
#   'Lng': 126.2925,
#   'Max Temp': 21.94,
#   'Humidity': 87,
#   'Cloudiness': 97,
#   'Wind Speed': 10.87,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:36:30'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 55.47,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'NZ',
#   'Date': '2021-12-04 22:35:05'},
#  {'City': 'Batouri',
#   'Lat': 4.4333,
#   'Lng': 14.3667,
#   'Max Temp': 72.43,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 1.5,
#   'Country': 'CM',
#   'Date': '2021-12-04 22:36:30'},
#  {'City': 'Oktyabrskiy',
#   'Lat': 54.4815,
#   'Lng': 53.471,
#   'Max Temp': 31.82,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.08,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:36:31'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 86.83,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'MX',
#   'Date': '2021-12-04 22:36:31'},
#  {'City': 'Lucapa',
#   'Lat': -8.4192,
#   'Lng': 20.7447,
#   'Max Temp': 65.95,
#   'Humidity': 97,
#   'Cloudiness': 89,
#   'Wind Speed': 3.04,
#   'Country': 'AO',
#   'Date': '2021-12-04 22:36:31'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 76.17,
#   'Humidity': 71,
#   'Cloudiness': 50,
#   'Wind Speed': 9.33,
#   'Country': 'PF',
#   'Date': '2021-12-04 22:36:32'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.59,
#   'Humidity': 75,
#   'Cloudiness': 87,
#   'Wind Speed': 11.95,
#   'Country': 'MV',
#   'Date': '2021-12-04 22:31:38'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 75.78,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 3.65,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:36:32'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 75.16,
#   'Humidity': 84,
#   'Cloudiness': 79,
#   'Wind Speed': 6.82,
#   'Country': 'EC',
#   'Date': '2021-12-04 22:36:32'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 77.25,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MU',
#   'Date': '2021-12-04 22:36:33'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 65.12,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:36:33'},
#  {'City': 'San Ramon',
#   'Lat': 37.7799,
#   'Lng': -121.978,
#   'Max Temp': 62.56,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-12-04 22:35:17'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 57.76,
#   'Humidity': 51,
#   'Cloudiness': 3,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:36:33'},
#  {'City': 'Roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 37.54,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'NO',
#   'Date': '2021-12-04 22:36:34'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -37.34,
#   'Humidity': 95,
#   'Cloudiness': 64,
#   'Wind Speed': 1.97,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:36:34'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 67.57,
#   'Humidity': 18,
#   'Cloudiness': 99,
#   'Wind Speed': 13.15,
#   'Country': 'ML',
#   'Date': '2021-12-04 22:36:34'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 13.01,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 5.88,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:31:42'},
#  {'City': 'Cabedelo',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 79.47,
#   'Humidity': 80,
#   'Cloudiness': 16,
#   'Wind Speed': 12.1,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:36:34'},
#  {'City': 'Iquitos',
#   'Lat': -3.7481,
#   'Lng': -73.2472,
#   'Max Temp': 78.84,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'PE',
#   'Date': '2021-12-04 22:36:35'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 64.9,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 17.45,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:36:35'},
#  {'City': 'Tymovskoye',
#   'Lat': 50.8456,
#   'Lng': 142.655,
#   'Max Temp': 5.27,
#   'Humidity': 91,
#   'Cloudiness': 84,
#   'Wind Speed': 7.25,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:36:35'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -24.41,
#   'Humidity': 99,
#   'Cloudiness': 91,
#   'Wind Speed': 6.11,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:36:35'},
#  {'City': 'Coalinga',
#   'Lat': 36.1397,
#   'Lng': -120.3602,
#   'Max Temp': 54.14,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.46,
#   'Country': 'US',
#   'Date': '2021-12-04 22:36:36'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 74.89,
#   'Humidity': 85,
#   'Cloudiness': 13,
#   'Wind Speed': 4.52,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:36:36'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 37.67,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-12-04 22:36:36'},
#  {'City': 'Kerur',
#   'Lat': 16.0167,
#   'Lng': 75.5667,
#   'Max Temp': 69.76,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 6.42,
#   'Country': 'IN',
#   'Date': '2021-12-04 22:36:36'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 37.8,
#   'Humidity': 58,
#   'Cloudiness': 4,
#   'Wind Speed': 16.44,
#   'Country': 'JP',
#   'Date': '2021-12-04 22:36:37'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 77.38,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'MU',
#   'Date': '2021-12-04 22:36:37'},
#  {'City': 'Cam Ranh',
#   'Lat': 11.9214,
#   'Lng': 109.1591,
#   'Max Temp': 73.36,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'VN',
#   'Date': '2021-12-04 22:36:37'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 37.31,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 27.09,
#   'Country': 'GB',
#   'Date': '2021-12-04 22:36:38'},
#  {'City': 'San Pedro',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 72.63,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'PH',
#   'Date': '2021-12-04 22:36:38'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.08,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 9.55,
#   'Country': 'PG',
#   'Date': '2021-12-04 22:37:38'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -23.8,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:37:38'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 62.53,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 0.47,
#   'Country': 'TL',
#   'Date': '2021-12-04 22:37:39'},
#  {'City': 'Poso',
#   'Lat': -1.3959,
#   'Lng': 120.7524,
#   'Max Temp': 80.29,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:37:39'},
#  {'City': 'Amuntai',
#   'Lat': -2.4177,
#   'Lng': 115.2494,
#   'Max Temp': 73.74,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:37:39'},
#  {'City': 'Abbeville',
#   'Lat': 50.1,
#   'Lng': 1.8333,
#   'Max Temp': 40.5,
#   'Humidity': 78,
#   'Cloudiness': 16,
#   'Wind Speed': 10.22,
#   'Country': 'FR',
#   'Date': '2021-12-04 22:37:39'},
#  {'City': 'Arkadak',
#   'Lat': 51.9326,
#   'Lng': 43.4978,
#   'Max Temp': 29.41,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:37:40'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 0.39,
#   'Humidity': 64,
#   'Cloudiness': 63,
#   'Wind Speed': 7.27,
#   'Country': 'GL',
#   'Date': '2021-12-04 22:34:22'},
#  {'City': 'Badou',
#   'Lat': 7.5833,
#   'Lng': 0.6,
#   'Max Temp': 77.09,
#   'Humidity': 53,
#   'Cloudiness': 84,
#   'Wind Speed': 1.68,
#   'Country': 'TG',
#   'Date': '2021-12-04 22:37:40'},
#  {'City': 'Gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 77.63,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 5.3,
#   'Country': 'GA',
#   'Date': '2021-12-04 22:37:39'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -7.44,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:37:40'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.46,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'AR',
#   'Date': '2021-12-04 22:35:03'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 76.55,
#   'Humidity': 83,
#   'Cloudiness': 29,
#   'Wind Speed': 9.28,
#   'Country': 'RE',
#   'Date': '2021-12-04 22:36:20'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 31.44,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 21.81,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:37:41'},
#  {'City': 'Tieling',
#   'Lat': 42.2931,
#   'Lng': 123.8414,
#   'Max Temp': 28.17,
#   'Humidity': 61,
#   'Cloudiness': 6,
#   'Wind Speed': 8.14,
#   'Country': 'CN',
#   'Date': '2021-12-04 22:37:41'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 59.02,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 11.99,
#   'Country': 'AR',
#   'Date': '2021-12-04 22:34:22'},
#  {'City': 'Gazimurskiy Zavod',
#   'Lat': 51.5461,
#   'Lng': 118.3266,
#   'Max Temp': 18.43,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:37:41'},
#  {'City': 'Auray',
#   'Lat': 47.6703,
#   'Lng': -2.9918,
#   'Max Temp': 47.75,
#   'Humidity': 78,
#   'Cloudiness': 96,
#   'Wind Speed': 17.74,
#   'Country': 'FR',
#   'Date': '2021-12-04 22:37:42'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 60.89,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 17.18,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:37:42'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -19.53,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:37:42'},
#  {'City': 'Kargasok',
#   'Lat': 59.0556,
#   'Lng': 80.8572,
#   'Max Temp': 19.92,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:37:43'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 84.34,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 18.41,
#   'Country': 'PG',
#   'Date': '2021-12-04 22:35:09'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 52.32,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'SA',
#   'Date': '2021-12-04 22:37:43'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 63.43,
#   'Humidity': 83,
#   'Cloudiness': 71,
#   'Wind Speed': 10.63,
#   'Country': 'PT',
#   'Date': '2021-12-04 22:37:43'},
#  {'City': 'Lebork',
#   'Lat': 54.5392,
#   'Lng': 17.7501,
#   'Max Temp': 34,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 2.91,
#   'Country': 'PL',
#   'Date': '2021-12-04 22:37:44'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 73.09,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:37:44'},
#  {'City': 'La Rinconada',
#   'Lat': 37.4873,
#   'Lng': -5.9826,
#   'Max Temp': 56.97,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'ES',
#   'Date': '2021-12-04 22:37:44'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': -21.01,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-12-04 22:35:05'},
#  {'City': 'Cozumel',
#   'Lat': 20.5083,
#   'Lng': -86.9458,
#   'Max Temp': 80.94,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 7,
#   'Country': 'MX',
#   'Date': '2021-12-04 22:37:44'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 68.25,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-12-04 22:36:37'},
#  {'City': 'Boyuibe',
#   'Lat': -20.4167,
#   'Lng': -63.2833,
#   'Max Temp': 68.92,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 8.23,
#   'Country': 'BO',
#   'Date': '2021-12-04 22:37:45'},
#  {'City': 'Arkhangelskoye',
#   'Lat': 55.8549,
#   'Lng': 35.3287,
#   'Max Temp': 26.62,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:37:45'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 22.15,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 5.88,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:35:14'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 64.31,
#   'Humidity': 75,
#   'Cloudiness': 89,
#   'Wind Speed': 11.97,
#   'Country': 'PT',
#   'Date': '2021-12-04 22:37:37'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 66.51,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 18.03,
#   'Country': 'MX',
#   'Date': '2021-12-04 22:37:46'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 68.04,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 23.26,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:37:46'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 84.61,
#   'Humidity': 70,
#   'Cloudiness': 55,
#   'Wind Speed': 12.5,
#   'Country': 'US',
#   'Date': '2021-12-04 22:37:46'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 42.71,
#   'Humidity': 72,
#   'Cloudiness': 2,
#   'Wind Speed': 6.2,
#   'Country': 'JP',
#   'Date': '2021-12-04 22:37:46'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 23.36,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'GL',
#   'Date': '2021-12-04 22:37:47'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 69.87,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:37:47'},
#  {'City': 'Panaba',
#   'Lat': 21.2833,
#   'Lng': -88.2667,
#   'Max Temp': 74.79,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 10.25,
#   'Country': 'MX',
#   'Date': '2021-12-04 22:37:47'},
#  {'City': 'Mahibadhoo',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 82.15,
#   'Humidity': 77,
#   'Cloudiness': 33,
#   'Wind Speed': 12.3,
#   'Country': 'MV',
#   'Date': '2021-12-04 22:37:47'},
#  {'City': 'Gusau',
#   'Lat': 12.1628,
#   'Lng': 6.6614,
#   'Max Temp': 72.75,
#   'Humidity': 25,
#   'Cloudiness': 61,
#   'Wind Speed': 8.88,
#   'Country': 'NG',
#   'Date': '2021-12-04 22:37:48'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': -29.25,
#   'Humidity': 75,
#   'Cloudiness': 41,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:37:48'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 84.36,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'TO',
#   'Date': '2021-12-04 22:34:24'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 26.42,
#   'Humidity': 61,
#   'Cloudiness': 95,
#   'Wind Speed': 1.41,
#   'Country': 'CN',
#   'Date': '2021-12-04 22:38:48'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -21.33,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 10.25,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:38:48'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 63.1,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:35:30'},
#  {'City': 'Porto Novo',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 84.02,
#   'Humidity': 81,
#   'Cloudiness': 71,
#   'Wind Speed': 6.58,
#   'Country': 'BJ',
#   'Date': '2021-12-04 22:38:49'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 66.02,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-12-04 22:38:49'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 55.81,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 11.21,
#   'Country': 'NZ',
#   'Date': '2021-12-04 22:38:49'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 38.79,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2021-12-04 22:35:06'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': -4.22,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 0.58,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:38:50'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 80.38,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'VU',
#   'Date': '2021-12-04 22:38:50'},
#  {'City': 'Dasoguz',
#   'Lat': 41.8363,
#   'Lng': 59.9666,
#   'Max Temp': 32.11,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'TM',
#   'Date': '2021-12-04 22:38:50'},
#  {'City': 'Mocuba',
#   'Lat': -16.8392,
#   'Lng': 36.9856,
#   'Max Temp': 79.23,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 7.23,
#   'Country': 'MZ',
#   'Date': '2021-12-04 22:38:50'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 69.85,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Country': 'PE',
#   'Date': '2021-12-04 22:34:52'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -34.56,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:38:51'},
#  {'City': 'Eydhafushi',
#   'Lat': 5.1033,
#   'Lng': 73.0708,
#   'Max Temp': 82.33,
#   'Humidity': 75,
#   'Cloudiness': 22,
#   'Wind Speed': 11.83,
#   'Country': 'MV',
#   'Date': '2021-12-04 22:38:51'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -19.37,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:38:51'},
#  {'City': 'Santa Cruz Cabralia',
#   'Lat': -16.2781,
#   'Lng': -39.0247,
#   'Max Temp': 77.23,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:38:51'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 79.92,
#   'Humidity': 75,
#   'Cloudiness': 35,
#   'Wind Speed': 21.5,
#   'Country': 'TC',
#   'Date': '2021-12-04 22:38:52'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 57.04,
#   'Humidity': 70,
#   'Cloudiness': 47,
#   'Wind Speed': 10.85,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:38:30'},
#  {'City': 'Xuddur',
#   'Lat': 4.1213,
#   'Lng': 43.8894,
#   'Max Temp': 72.79,
#   'Humidity': 58,
#   'Cloudiness': 11,
#   'Wind Speed': 11.12,
#   'Country': 'SO',
#   'Date': '2021-12-04 22:38:52'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 77.4,
#   'Humidity': 71,
#   'Cloudiness': 64,
#   'Wind Speed': 3,
#   'Country': 'MU',
#   'Date': '2021-12-04 22:38:52'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 56.53,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 20.78,
#   'Country': 'CL',
#   'Date': '2021-12-04 22:38:53'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 61.29,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 19.33,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:38:53'},
#  {'City': 'Costinesti',
#   'Lat': 43.95,
#   'Lng': 28.6333,
#   'Max Temp': 39.02,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.71,
#   'Country': 'RO',
#   'Date': '2021-12-04 22:38:53'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 65.89,
#   'Humidity': 68,
#   'Cloudiness': 37,
#   'Wind Speed': 9.13,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:35:04'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 15.82,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2021-12-04 22:35:14'},
#  {'City': 'Lazaro Cardenas',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 81.95,
#   'Humidity': 71,
#   'Cloudiness': 44,
#   'Wind Speed': 5.97,
#   'Country': 'MX',
#   'Date': '2021-12-04 22:38:53'},
#  {'City': 'Sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 76.95,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 1.52,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:38:54'},
#  {'City': 'Borovoy',
#   'Lat': 55.4333,
#   'Lng': 86.0833,
#   'Max Temp': 25.88,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:38:54'},
#  {'City': 'Mitu',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 71.42,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.31,
#   'Country': 'CO',
#   'Date': '2021-12-04 22:36:26'},
#  {'City': 'Anito',
#   'Lat': 12.4497,
#   'Lng': 125.2886,
#   'Max Temp': 76.23,
#   'Humidity': 84,
#   'Cloudiness': 89,
#   'Wind Speed': 16.62,
#   'Country': 'PH',
#   'Date': '2021-12-04 22:38:54'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 83.21,
#   'Humidity': 78,
#   'Cloudiness': 28,
#   'Wind Speed': 19.98,
#   'Country': 'KI',
#   'Date': '2021-12-04 22:33:54'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 64.63,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-12-04 22:38:18'},
#  {'City': 'Galle',
#   'Lat': 6.0367,
#   'Lng': 80.217,
#   'Max Temp': 77.74,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Country': 'LK',
#   'Date': '2021-12-04 22:38:55'},
#  {'City': 'Dalbandin',
#   'Lat': 28.8947,
#   'Lng': 64.4101,
#   'Max Temp': 53.2,
#   'Humidity': 60,
#   'Cloudiness': 3,
#   'Wind Speed': 5.5,
#   'Country': 'PK',
#   'Date': '2021-12-04 22:38:55'},
#  {'City': 'Mao',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 57.76,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'ES',
#   'Date': '2021-12-04 22:38:55'},
#  {'City': 'Kawambwa',
#   'Lat': -9.7915,
#   'Lng': 29.0791,
#   'Max Temp': 65.32,
#   'Humidity': 57,
#   'Cloudiness': 16,
#   'Wind Speed': 1.81,
#   'Country': 'ZM',
#   'Date': '2021-12-04 22:38:56'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 62.33,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'CL',
#   'Date': '2021-12-04 22:38:56'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 73.96,
#   'Humidity': 90,
#   'Cloudiness': 55,
#   'Wind Speed': 10.13,
#   'Country': 'PH',
#   'Date': '2021-12-04 22:38:56'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -21.59,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 5.14,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:38:56'},
#  {'City': 'Novobirilyussy',
#   'Lat': 56.9514,
#   'Lng': 90.6661,
#   'Max Temp': 18.54,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 10.92,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:38:57'},
#  {'City': 'Ornskoldsvik',
#   'Lat': 63.2909,
#   'Lng': 18.7153,
#   'Max Temp': 9.55,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'SE',
#   'Date': '2021-12-04 22:34:47'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 82.29,
#   'Humidity': 78,
#   'Cloudiness': 53,
#   'Wind Speed': 6.91,
#   'Country': 'NU',
#   'Date': '2021-12-04 22:38:57'},
#  {'City': 'Malakal',
#   'Lat': 9.5334,
#   'Lng': 31.6605,
#   'Max Temp': 80.8,
#   'Humidity': 31,
#   'Cloudiness': 5,
#   'Wind Speed': 5.35,
#   'Country': 'SS',
#   'Date': '2021-12-04 22:38:57'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 58.12,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:38:57'},
#  {'City': 'Pouebo',
#   'Lat': -20.4,
#   'Lng': 164.5667,
#   'Max Temp': 82.85,
#   'Humidity': 68,
#   'Cloudiness': 8,
#   'Wind Speed': 9.48,
#   'Country': 'NC',
#   'Date': '2021-12-04 22:38:58'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 76.33,
#   'Humidity': 84,
#   'Cloudiness': 83,
#   'Wind Speed': 18.05,
#   'Country': 'NC',
#   'Date': '2021-12-04 22:38:58'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 66.16,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 13.96,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:38:09'},
#  {'City': 'Magadan',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': -0.4,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:39:58'},
#  {'City': 'Otradnoye',
#   'Lat': 59.7775,
#   'Lng': 30.8181,
#   'Max Temp': 13.17,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 6.04,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:39:58'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 71.44,
#   'Humidity': 43,
#   'Cloudiness': 35,
#   'Wind Speed': 18.41,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:39:59'},
#  {'City': 'Acarau',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 80.71,
#   'Humidity': 79,
#   'Cloudiness': 36,
#   'Wind Speed': 14.16,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:39:59'},
#  {'City': 'Olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 82.13,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:37:46'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 77.05,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:39:59'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.27,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.12,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:40:00'},
#  {'City': 'Xining',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 25.43,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'CN',
#   'Date': '2021-12-04 22:40:00'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 64.04,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.52,
#   'Country': 'UY',
#   'Date': '2021-12-04 22:40:00'},
#  {'City': 'Iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 7.41,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 7.81,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:40:01'},
#  {'City': 'Formosa Do Rio Preto',
#   'Lat': -11.0483,
#   'Lng': -45.1931,
#   'Max Temp': 68.76,
#   'Humidity': 98,
#   'Cloudiness': 89,
#   'Wind Speed': 3.18,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:40:01'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 60.85,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.78,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:40:01'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 64.02,
#   'Humidity': 24,
#   'Cloudiness': 2,
#   'Wind Speed': 12.93,
#   'Country': 'NE',
#   'Date': '2021-12-04 22:40:01'},
#  {'City': 'Buin',
#   'Lat': -33.7333,
#   'Lng': -70.75,
#   'Max Temp': 91.72,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 7.54,
#   'Country': 'CL',
#   'Date': '2021-12-04 22:40:02'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 34.72,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 19.98,
#   'Country': 'FO',
#   'Date': '2021-12-04 22:40:02'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 31.59,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 13.29,
#   'Country': 'GL',
#   'Date': '2021-12-04 22:40:02'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 81.59,
#   'Humidity': 74,
#   'Cloudiness': 57,
#   'Wind Speed': 14.9,
#   'Country': 'GW',
#   'Date': '2021-12-04 22:40:02'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 26.11,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-12-04 22:40:03'},
#  {'City': 'Along',
#   'Lat': 28.1667,
#   'Lng': 94.7667,
#   'Max Temp': 55.26,
#   'Humidity': 84,
#   'Cloudiness': 24,
#   'Wind Speed': 1.48,
#   'Country': 'IN',
#   'Date': '2021-12-04 22:40:03'},
#  {'City': 'Mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 67.06,
#   'Humidity': 48,
#   'Cloudiness': 52,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:40:03'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 35.11,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 27.81,
#   'Country': 'GL',
#   'Date': '2021-12-04 22:40:04'},
#  {'City': 'Roebourne',
#   'Lat': -20.7833,
#   'Lng': 117.1333,
#   'Max Temp': 90.73,
#   'Humidity': 26,
#   'Cloudiness': 48,
#   'Wind Speed': 14.99,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:40:04'},
#  {'City': 'Sainte-Anne-Des-Monts',
#   'Lat': 49.124,
#   'Lng': -66.4924,
#   'Max Temp': 24.67,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 21.85,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:40:04'},
#  {'City': 'Mecca',
#   'Lat': 21.4267,
#   'Lng': 39.8261,
#   'Max Temp': 72.54,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 0.6,
#   'Country': 'SA',
#   'Date': '2021-12-04 22:40:05'},
#  {'City': 'The Pas',
#   'Lat': 53.8251,
#   'Lng': -101.2541,
#   'Max Temp': 8.62,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:40:05'},
#  {'City': 'Nehe',
#   'Lat': 48.4833,
#   'Lng': 124.8333,
#   'Max Temp': 10.33,
#   'Humidity': 96,
#   'Cloudiness': 70,
#   'Wind Speed': 8.25,
#   'Country': 'CN',
#   'Date': '2021-12-04 22:40:05'},
#  {'City': 'Zwedru',
#   'Lat': 6.0667,
#   'Lng': -8.1281,
#   'Max Temp': 75.51,
#   'Humidity': 87,
#   'Cloudiness': 42,
#   'Wind Speed': 2.66,
#   'Country': 'LR',
#   'Date': '2021-12-04 22:40:05'},
#  {'City': 'Vierzon',
#   'Lat': 47.2101,
#   'Lng': 2.0625,
#   'Max Temp': 39.79,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 13.06,
#   'Country': 'FR',
#   'Date': '2021-12-04 22:40:06'},
#  {'City': 'Seymchan',
#   'Lat': 62.8833,
#   'Lng': 152.4333,
#   'Max Temp': -40.59,
#   'Humidity': 99,
#   'Cloudiness': 96,
#   'Wind Speed': 1.07,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:40:06'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 66.61,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:40:06'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 25.52,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 6.24,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:40:06'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 81.63,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'MX',
#   'Date': '2021-12-04 22:40:07'},
#  {'City': 'Barcelos',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 50.29,
#   'Humidity': 78,
#   'Cloudiness': 36,
#   'Wind Speed': 6.76,
#   'Country': 'PT',
#   'Date': '2021-12-04 22:40:07'},
#  {'City': 'Leyland',
#   'Lat': 53.6979,
#   'Lng': -2.6876,
#   'Max Temp': 46.18,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'GB',
#   'Date': '2021-12-04 22:36:29'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': -4.65,
#   'Humidity': 91,
#   'Cloudiness': 71,
#   'Wind Speed': 5.12,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:40:07'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 78.76,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'GA',
#   'Date': '2021-12-04 22:36:19'},
#  {'City': 'Karacakoy',
#   'Lat': 41.4029,
#   'Lng': 28.3834,
#   'Max Temp': 50.04,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 5.21,
#   'Country': 'TR',
#   'Date': '2021-12-04 22:40:07'},
#  {'City': 'Gavrilov-Yam',
#   'Lat': 57.3018,
#   'Lng': 39.8533,
#   'Max Temp': 15.64,
#   'Humidity': 98,
#   'Cloudiness': 95,
#   'Wind Speed': 3.27,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:40:08'},
#  {'City': 'Nyakabindi',
#   'Lat': -2.6333,
#   'Lng': 33.9833,
#   'Max Temp': 65.19,
#   'Humidity': 82,
#   'Cloudiness': 94,
#   'Wind Speed': 5.12,
#   'Country': 'TZ',
#   'Date': '2021-12-04 22:40:08'},
#  {'City': 'Dalvik',
#   'Lat': 65.9702,
#   'Lng': -18.5286,
#   'Max Temp': 15.73,
#   'Humidity': 79,
#   'Cloudiness': 37,
#   'Wind Speed': 8.21,
#   'Country': 'IS',
#   'Date': '2021-12-04 22:40:08'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 66.83,
#   'Humidity': 66,
#   'Cloudiness': 97,
#   'Wind Speed': 9.28,
#   'Country': 'PT',
#   'Date': '2021-12-04 22:36:37'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 28.56,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 41.47,
#   'Country': 'GL',
#   'Date': '2021-12-04 22:40:09'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -27.58,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:37:48'},
#  {'City': 'Tateyama',
#   'Lat': 34.9833,
#   'Lng': 139.8667,
#   'Max Temp': 47.1,
#   'Humidity': 55,
#   'Cloudiness': 10,
#   'Wind Speed': 11.03,
#   'Country': 'JP',
#   'Date': '2021-12-04 22:40:09'},
#  {'City': 'Tepalcatepec',
#   'Lat': 19.1833,
#   'Lng': -102.85,
#   'Max Temp': 89.62,
#   'Humidity': 33,
#   'Cloudiness': 34,
#   'Wind Speed': 3.78,
#   'Country': 'MX',
#   'Date': '2021-12-04 22:40:09'},
#  {'City': 'Fort-Shevchenko',
#   'Lat': 44.5086,
#   'Lng': 50.263,
#   'Max Temp': 46.11,
#   'Humidity': 80,
#   'Cloudiness': 44,
#   'Wind Speed': 22.48,
#   'Country': 'KZ',
#   'Date': '2021-12-04 22:41:09'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': -22.95,
#   'Humidity': 98,
#   'Cloudiness': 25,
#   'Wind Speed': 3.33,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:10'},
#  {'City': 'Muroto',
#   'Lat': 33.2833,
#   'Lng': 134.15,
#   'Max Temp': 41.04,
#   'Humidity': 64,
#   'Cloudiness': 53,
#   'Wind Speed': 10.09,
#   'Country': 'JP',
#   'Date': '2021-12-04 22:41:10'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 63.57,
#   'Humidity': 64,
#   'Cloudiness': 2,
#   'Wind Speed': 13.13,
#   'Country': 'CL',
#   'Date': '2021-12-04 22:38:32'},
#  {'City': 'Outjo',
#   'Lat': -20.1167,
#   'Lng': 16.15,
#   'Max Temp': 63.19,
#   'Humidity': 31,
#   'Cloudiness': 9,
#   'Wind Speed': 8.55,
#   'Country': 'NA',
#   'Date': '2021-12-04 22:41:10'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 62.8,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 12.88,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:39:00'},
#  {'City': 'Sri Aman',
#   'Lat': 1.2376,
#   'Lng': 111.4621,
#   'Max Temp': 75.25,
#   'Humidity': 100,
#   'Cloudiness': 89,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Date': '2021-12-04 22:41:11'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 63.19,
#   'Humidity': 86,
#   'Cloudiness': 92,
#   'Wind Speed': 0.87,
#   'Country': 'PT',
#   'Date': '2021-12-04 22:41:11'},
#  {'City': 'Opuwo',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 68.04,
#   'Humidity': 27,
#   'Cloudiness': 64,
#   'Wind Speed': 5.48,
#   'Country': 'NA',
#   'Date': '2021-12-04 22:41:11'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 85.51,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 2.33,
#   'Country': 'SB',
#   'Date': '2021-12-04 22:41:11'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 21.4,
#   'Humidity': 52,
#   'Cloudiness': 5,
#   'Wind Speed': 7.99,
#   'Country': 'CN',
#   'Date': '2021-12-04 22:41:12'},
#  {'City': 'Novi Travnik',
#   'Lat': 44.1711,
#   'Lng': 17.6575,
#   'Max Temp': 30.13,
#   'Humidity': 84,
#   'Cloudiness': 87,
#   'Wind Speed': 5.64,
#   'Country': 'BA',
#   'Date': '2021-12-04 22:41:12'},
#  {'City': 'Karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 88.66,
#   'Humidity': 27,
#   'Cloudiness': 49,
#   'Wind Speed': 15.12,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:41:12'},
#  {'City': 'Golden',
#   'Lat': 39.7555,
#   'Lng': -105.2211,
#   'Max Temp': 66.69,
#   'Humidity': 24,
#   'Cloudiness': 2,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2021-12-04 22:36:17'},
#  {'City': 'Waddan',
#   'Lat': 29.1614,
#   'Lng': 16.139,
#   'Max Temp': 50.23,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'LY',
#   'Date': '2021-12-04 22:41:13'},
#  {'City': 'Cumra',
#   'Lat': 37.5732,
#   'Lng': 32.7745,
#   'Max Temp': 42.94,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'TR',
#   'Date': '2021-12-04 22:41:13'},
#  {'City': 'Inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 77.07,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 11.92,
#   'Country': 'MZ',
#   'Date': '2021-12-04 22:41:13'},
#  {'City': 'Fuerte Olimpo',
#   'Lat': -21.0415,
#   'Lng': -57.8738,
#   'Max Temp': 77.5,
#   'Humidity': 82,
#   'Cloudiness': 94,
#   'Wind Speed': 2.89,
#   'Country': 'PY',
#   'Date': '2021-12-04 22:41:13'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 66.15,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CL',
#   'Date': '2021-12-04 22:41:14'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 78.85,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CK',
#   'Date': '2021-12-04 22:36:14'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 76.95,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:41:14'},
#  {'City': 'Imeni Poliny Osipenko',
#   'Lat': 52.4201,
#   'Lng': 136.4853,
#   'Max Temp': -5.19,
#   'Humidity': 90,
#   'Cloudiness': 91,
#   'Wind Speed': 12.73,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:14'},
#  {'City': 'Salinas',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Max Temp': 65.05,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-12-04 22:41:15'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 72.23,
#   'Humidity': 97,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-12-04 22:41:15'},
#  {'City': 'Ayan',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 6.33,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.07,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:15'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 17.94,
#   'Humidity': 84,
#   'Cloudiness': 13,
#   'Wind Speed': 21.88,
#   'Country': 'NO',
#   'Date': '2021-12-04 22:41:15'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -20.6,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:11'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -21.01,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-12-04 22:41:16'},
#  {'City': 'Esso',
#   'Lat': 55.9333,
#   'Lng': 158.7,
#   'Max Temp': 19.17,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 18.86,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:16'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 19.24,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Country': 'SJ',
#   'Date': '2021-12-04 22:41:16'},
#  {'City': 'Chabahar',
#   'Lat': 25.2919,
#   'Lng': 60.643,
#   'Max Temp': 73.9,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 7.07,
#   'Country': 'IR',
#   'Date': '2021-12-04 22:41:16'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -18.04,
#   'Humidity': 94,
#   'Cloudiness': 87,
#   'Wind Speed': 5.35,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:17'},
#  {'City': 'Novoilinsk',
#   'Lat': 51.6829,
#   'Lng': 108.7143,
#   'Max Temp': 15.89,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 2.75,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:17'},
#  {'City': 'Tongren',
#   'Lat': 27.7172,
#   'Lng': 109.1853,
#   'Max Temp': 48.34,
#   'Humidity': 78,
#   'Cloudiness': 2,
#   'Wind Speed': 1.19,
#   'Country': 'CN',
#   'Date': '2021-12-04 22:41:17'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 26.49,
#   'Humidity': 54,
#   'Cloudiness': 87,
#   'Wind Speed': 4.81,
#   'Country': 'CN',
#   'Date': '2021-12-04 22:40:08'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -22.25,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 11.05,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:18'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.89,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'MY',
#   'Date': '2021-12-04 22:36:19'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 15.71,
#   'Humidity': 81,
#   'Cloudiness': 23,
#   'Wind Speed': 14.16,
#   'Country': 'IS',
#   'Date': '2021-12-04 22:41:18'},
#  {'City': 'Harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 79.81,
#   'Humidity': 82,
#   'Cloudiness': 6,
#   'Wind Speed': 7.85,
#   'Country': 'LR',
#   'Date': '2021-12-04 22:41:18'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 11.68,
#   'Humidity': 96,
#   'Cloudiness': 49,
#   'Wind Speed': 3.09,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:18'},
#  {'City': 'Colac',
#   'Lat': -38.3333,
#   'Lng': 143.5833,
#   'Max Temp': 60.15,
#   'Humidity': 45,
#   'Cloudiness': 85,
#   'Wind Speed': 7.16,
#   'Country': 'AU',
#   'Date': '2021-12-04 22:41:19'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 73.72,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 27.11,
#   'Country': 'AR',
#   'Date': '2021-12-04 22:41:19'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 71.46,
#   'Humidity': 26,
#   'Cloudiness': 20,
#   'Wind Speed': 20.71,
#   'Country': 'AR',
#   'Date': '2021-12-04 22:41:19'},
#  {'City': 'Bokoro',
#   'Lat': 12.3807,
#   'Lng': 17.0568,
#   'Max Temp': 78.12,
#   'Humidity': 18,
#   'Cloudiness': 51,
#   'Wind Speed': 13.56,
#   'Country': 'TD',
#   'Date': '2021-12-04 22:41:19'},
#  {'City': 'Suoyarvi',
#   'Lat': 62.0833,
#   'Lng': 32.35,
#   'Max Temp': 0.09,
#   'Humidity': 91,
#   'Cloudiness': 22,
#   'Wind Speed': 7.05,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:41:20'},
#  {'City': 'Jefferson City',
#   'Lat': 38.5767,
#   'Lng': -92.1735,
#   'Max Temp': 55.31,
#   'Humidity': 39,
#   'Cloudiness': 1,
#   'Wind Speed': 11.99,
#   'Country': 'US',
#   'Date': '2021-12-04 22:41:20'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 31.06,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 9.37,
#   'Country': 'IS',
#   'Date': '2021-12-04 22:42:20'},
#  {'City': 'Thunder Bay',
#   'Lat': 48.4001,
#   'Lng': -89.3168,
#   'Max Temp': 19.99,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:38:13'},
#  {'City': 'Kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 79.38,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:42:20'},
#  {'City': 'Jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 42.13,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 4.05,
#   'Country': 'NP',
#   'Date': '2021-12-04 22:39:03'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -40.41,
#   'Humidity': 100,
#   'Cloudiness': 58,
#   'Wind Speed': 2.59,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:37:43'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 54.81,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2021-12-04 22:42:21'},
#  {'City': 'Uray',
#   'Lat': 60.1247,
#   'Lng': 64.7758,
#   'Max Temp': 21.94,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:42:21'},
#  {'City': 'Belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 77.5,
#   'Humidity': 86,
#   'Cloudiness': 47,
#   'Wind Speed': 5.37,
#   'Country': 'BR',
#   'Date': '2021-12-04 22:42:21'},
#  {'City': 'Orekhovo-Zuevo',
#   'Lat': 55.8083,
#   'Lng': 38.979,
#   'Max Temp': 22.89,
#   'Humidity': 98,
#   'Cloudiness': 85,
#   'Wind Speed': 3.31,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:42:22'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 59.94,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Country': 'NZ',
#   'Date': '2021-12-04 22:42:22'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 72.5,
#   'Humidity': 73,
#   'Cloudiness': 49,
#   'Wind Speed': 12.21,
#   'Country': 'NZ',
#   'Date': '2021-12-04 22:42:22'},
#  {'City': 'Sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 77.56,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 9.6,
#   'Country': 'GF',
#   'Date': '2021-12-04 22:42:22'},
#  {'City': 'Akdagmadeni',
#   'Lat': 39.6603,
#   'Lng': 35.8836,
#   'Max Temp': 37.22,
#   'Humidity': 73,
#   'Cloudiness': 95,
#   'Wind Speed': 5.32,
#   'Country': 'TR',
#   'Date': '2021-12-04 22:42:23'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 70.07,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 4.43,
#   'Country': 'AO',
#   'Date': '2021-12-04 22:42:23'},
#  {'City': 'Khomutovka',
#   'Lat': 51.9207,
#   'Lng': 34.5619,
#   'Max Temp': 25.43,
#   'Humidity': 94,
#   'Cloudiness': 57,
#   'Wind Speed': 4.61,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:42:23'},
#  {'City': 'Amalfi',
#   'Lat': 6.9102,
#   'Lng': -75.0776,
#   'Max Temp': 62.22,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Country': 'CO',
#   'Date': '2021-12-04 22:42:23'},
#  {'City': 'Sobolevo',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 27.21,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Country': 'RU',
#   'Date': '2021-12-04 22:42:24'},
#  {'City': 'Singkawang',
#   'Lat': 0.9,
#   'Lng': 109,
#   'Max Temp': 75.78,
#   'Humidity': 93,
#   'Cloudiness': 92,
#   'Wind Speed': 4.32,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:42:24'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 60.39,
#   'Humidity': 89,
#   'Cloudiness': 6,
#   'Wind Speed': 4.79,
#   'Country': 'NA',
#   'Date': '2021-12-04 22:42:24'},
#  {'City': 'Mizan Teferi',
#   'Lat': 6.9833,
#   'Lng': 35.5833,
#   'Max Temp': 64.45,
#   'Humidity': 67,
#   'Cloudiness': 10,
#   'Wind Speed': 2.91,
#   'Country': 'ET',
#   'Date': '2021-12-04 22:42:25'},
#  {'City': 'Sorkjosen',
#   'Lat': 69.8,
#   'Lng': 20.9333,
#   'Max Temp': 12.74,
#   'Humidity': 76,
#   'Cloudiness': 3,
#   'Wind Speed': 11.48,
#   'Country': 'NO',
#   'Date': '2021-12-04 22:42:25'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 81.21,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Country': 'BB',
#   'Date': '2021-12-04 22:42:25'},
#  {'City': 'Yellapur',
#   'Lat': 14.9667,
#   'Lng': 74.7167,
#   'Max Temp': 64.96,
#   'Humidity': 99,
#   'Cloudiness': 51,
#   'Wind Speed': 0.98,
#   'Country': 'IN',
#   'Date': '2021-12-04 22:42:25'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 72.07,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-12-04 22:39:36'},
#  {'City': 'Prieska',
#   'Lat': -29.6641,
#   'Lng': 22.7474,
#   'Max Temp': 66.04,
#   'Humidity': 41,
#   'Cloudiness': 99,
#   'Wind Speed': 4.09,
#   'Country': 'ZA',
#   'Date': '2021-12-04 22:42:26'},
#  {'City': 'Nola',
#   'Lat': 40.922,
#   'Lng': 14.5329,
#   'Max Temp': 57.38,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 4,
#   'Country': 'IT',
#   'Date': '2021-12-04 22:42:26'},
#  {'City': 'Stokmarknes',
#   'Lat': 68.5646,
#   'Lng': 14.9108,
#   'Max Temp': 24.78,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'NO',
#   'Date': '2021-12-04 22:42:26'},
#  {'City': 'Pascagoula',
#   'Lat': 30.3658,
#   'Lng': -88.5561,
#   'Max Temp': 71.6,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-12-04 22:42:27'},
#  {'City': 'Moen',
#   'Lat': 69.1304,
#   'Lng': 18.6123,
#   'Max Temp': 19.47,
#   'Humidity': 84,
#   'Cloudiness': 7,
#   'Wind Speed': 0,
#   'Country': 'NO',
#   'Date': '2021-12-04 22:42:27'},
#  {'City': 'Pihuamo',
#   'Lat': 19.2499,
#   'Lng': -103.3828,
#   'Max Temp': 81.63,
#   'Humidity': 52,
#   'Cloudiness': 85,
#   'Wind Speed': 3.44,
#   'Country': 'MX',
#   'Date': '2021-12-04 22:42:27'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 62.1,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'NA',
#   'Date': '2021-12-04 22:42:28'},
#  {'City': 'Kralendijk',
#   'Lat': 12.15,
#   'Lng': -68.2667,
#   'Max Temp': 82.38,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'BQ',
#   'Date': '2021-12-04 22:42:28'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 58.12,
#   'Humidity': 60,
#   'Cloudiness': 97,
#   'Wind Speed': 10.18,
#   'Country': 'JP',
#   'Date': '2021-12-04 22:42:28'},
#  {'City': 'Dera Bugti',
#   'Lat': 29.0307,
#   'Lng': 69.151,
#   'Max Temp': 57.97,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'PK',
#   'Date': '2021-12-04 22:42:29'},
#  {'City': 'Nouakchott',
#   'Lat': 18.0858,
#   'Lng': -15.9785,
#   'Max Temp': 76.93,
#   'Humidity': 37,
#   'Cloudiness': 100,
#   'Wind Speed': 9.98,
#   'Country': 'MR',
#   'Date': '2021-12-04 22:42:29'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 8.15,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-12-04 22:42:29'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 66.47,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'JP',
#   'Date': '2021-12-04 22:42:30'},
#  {'City': 'Nechi',
#   'Lat': 8.0942,
#   'Lng': -74.7757,
#   'Max Temp': 76.96,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 1.25,
#   'Country': 'CO',
#   'Date': '2021-12-04 22:42:30'},
#  {'City': 'Lewistown',
#   'Lat': 40.5992,
#   'Lng': -77.5714,
#   'Max Temp': 47.61,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-12-04 22:42:30'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 76.26,
#   'Humidity': 71,
#   'Cloudiness': 95,
#   'Wind Speed': 10.78,
#   'Country': 'CV',
#   'Date': '2021-12-04 22:42:30'},
#  {'City': 'Pinawa',
#   'Lat': 50.1489,
#   'Lng': -95.8811,
#   'Max Temp': 12.9,
#   'Humidity': 92,
#   'Cloudiness': 59,
#   'Wind Speed': 3.74,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:42:31'},
#  {'City': 'Goba',
#   'Lat': 7.0167,
#   'Lng': 39.9833,
#   'Max Temp': 46.56,
#   'Humidity': 78,
#   'Cloudiness': 10,
#   'Wind Speed': 4.65,
#   'Country': 'ET',
#   'Date': '2021-12-04 22:42:31'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 59.36,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 3.13,
#   'Country': 'YE',
#   'Date': '2021-12-04 22:42:31'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 74.66,
#   'Humidity': 66,
#   'Cloudiness': 7,
#   'Wind Speed': 7.4,
#   'Country': 'IN',
#   'Date': '2021-12-04 22:42:32'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 42.66,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-12-04 22:42:32'},
#  {'City': 'Balikpapan',
#   'Lat': -1.2675,
#   'Lng': 116.8289,
#   'Max Temp': 76.19,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'ID',
#   'Date': '2021-12-04 22:41:06'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 30.67,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 27.63,
#   'Country': 'CA',
#   'Date': '2021-12-04 22:41:04'},
#  {'City': 'Bandrele',
#   'Lat': -12.9067,
#   'Lng': 45.1914,
#   'Max Temp': 80.35,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'YT',
#   'Date': '2021-12-04 22:42:32'}]
